# %% [markdown]
# # Compare trials and spikes by session

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import matplotlib.pyplot as plt
import qgrid
#from nma_class import loader
from nma_class_Copy1 import loader

# %matplotlib inline

# %% [markdown]
# ### To compare the trials
# Output:
#
# Table with
#
# session name;	all trials;	correct trials;	diff contrast;	no contrast;	%Correct;	%Contrast;	% 0contrast

# %%
# for the first session: 

# link to parent folder with all datasets
main_folder = '/Volumes/GoogleDrive/My Drive/NMA_Dataset/Dataset_1'

from nma_class_Copy1 import loader
#to load older sessions 
loader = loader(main_folder)
all_session_folders, all_session_names = loader.get_available_session()
# load default session 
# put here any integer instead of 0 or directly the folder of the session

session_folder = all_session_folders[0]
session_name =  all_session_names[0]
session = loader.load_session(session_folder, fast=True)

spikes_df = session['spikes_df']
clusters_df = session['clusters_df']
trials_df = session['trials_df']

correct_df = trials_df.loc[(trials_df['feedback type']==1)]
diff_contrasts_df = correct_df.loc[(correct_df['stim contrast left']!=(correct_df['stim contrast right']))]
no_contrasts_df = correct_df.loc[(correct_df['stim contrast left']==0) & (correct_df['stim contrast right']==0)]


all_t = len(trials_df)
crrct = len(correct_df)
cont = len(diff_contrasts_df)
nocont = len(no_contrasts_df)

df1 = ''
df1 = {'session name': [session_name],
      'all trials': [all_t], 
      'correct trials': [crrct], 
      'diff contrast t': [cont], 
      'no contras': [nocont], 
      '%Correct': [round(crrct/all_t*100,2)], 
       '%Contrast':[round(cont/crrct*100,2)], 
       '% 0contrast':[round(nocont/crrct*100,2)]}

df2 = pd.DataFrame(data=df1)


df3 = df2

# %%
df3
# Out:
#       session name  all trials  correct trials  diff contrast t  no contras  \
# 0  Cori_2016-12-14         214             141               57          84
#
#    %Correct  %Contrast  % 0contrast
# 0     65.89      40.43        59.57

# %%
# for all the other sessions

# link to parent folder with all datasets
main_folder = '/Volumes/GoogleDrive/My Drive/NMA_Dataset/Dataset_1'

from nma_class_Copy1 import loader
#to load older sessions 
loader = loader(main_folder)
all_session_folders, all_session_names = loader.get_available_session()
# load default session 
# put here any integer instead of 0 or directly the folder of the session
for i in range(1,len(all_session_folders)): 
    session_folder = all_session_folders[i]
    session_name =  all_session_names[i]
    session = loader.load_session(session_folder, fast=True)

    spikes_df = session['spikes_df']
    clusters_df = session['clusters_df']
    trials_df = session['trials_df']
    
    correct_df = trials_df.loc[(trials_df['feedback type']==1)]
    diff_contrasts_df = correct_df.loc[(correct_df['stim contrast left']!=(correct_df['stim contrast right']))]
    no_contrasts_df = correct_df.loc[(correct_df['stim contrast left']==0) & (correct_df['stim contrast right']==0)]


    all_t = len(trials_df)
    crrct = len(correct_df)
    cont = len(diff_contrasts_df)
    nocont = len(no_contrasts_df)

    df1 = ''
    df1 = {'session name': [session_name],
          'all trials': [all_t], 
          'correct trials': [crrct], 
          'diff contrast t': [cont], 
          'no contras': [nocont], 
          '%Correct': [round(crrct/all_t*100,2)], 
           '%Contrast':[round(cont/crrct*100,2)], 
           '%0contrast':[round(nocont/crrct*100,2)]}

    df2 = pd.DataFrame(data=df1)
    
    
    df3 = df3.append(df2)

# %%
df3
# Out:
#            session name  all trials  correct trials  diff contrast t  \
# 0       Cori_2016-12-14         214             141               57
# 0       Cori_2016-12-17         251             159               57
# 0       Cori_2016-12-18         228             151               55
# 0  Forssmann_2017-11-01         249             166               50
# 0  Forssmann_2017-11-02         254             168               67
# 0  Forssmann_2017-11-04         290             215               81
# 0  Forssmann_2017-11-05         252             169               57
# 0      Hench_2017-06-15         250             161               85
# 0      Hench_2017-06-16         372             255              108
# 0      Hench_2017-06-17         447             277              123
# 0      Hench_2017-06-18         342             272              101
# 0  Lederberg_2017-12-05         340             251              100
# 0  Lederberg_2017-12-06         300             239              100
# 0  Lederberg_2017-12-07         268             186               72
# 0  Lederberg_2017-12-08         404             309              138
# 0  Lederberg_2017-12-09         280             201               82
# 0  Lederberg_2017-12-10         224             186               85
# 0  Lederberg_2017-12-11         316             247              101
# 0      Moniz_2017-05-15         247             142               61
# 0      Moniz_2017-05-16         235             139               49
# 0      Moniz_2017-05-18         124              66               27
# 0     Muller_2017-01-07         444             311              115
# 0     Muller_2017-01-08         151             102               43
# 0     Muller_2017-01-09         187             109               47
# 0    Radnitz_2017-01-08         261             188               75
# 0    Radnitz_2017-01-09         178             130               60
# 0    Radnitz_2017-01-10         253             159               68
# 0    Radnitz_2017-01-11         142              85               42
# 0    Radnitz_2017-01-12         128              75               31
# 0   Richards_2017-10-29         143              72               26
# 0   Richards_2017-10-30         237             164               73
# 0   Richards_2017-10-31         260             186               96
# 0   Richards_2017-11-01         191             129               62
# 0   Richards_2017-11-02         296             176               90
# 0      Tatum_2017-12-06         311             240               98
# 0      Tatum_2017-12-07         258             188               87
# 0      Tatum_2017-12-08         181             132               64
# 0      Tatum_2017-12-09         199             131               56
# 0    Theiler_2017-10-11         343             246               78
#
#    no contras  %Correct  %Contrast  % 0contrast
# 0          84     65.89      40.43        59.57
# 0          98     63.35      35.85        61.64
# 0          93     66.23      36.42        61.59
# 0         112     66.67      30.12        67.47
# 0          94     66.14      39.88        55.95
# 0         129     74.14      37.67        60.00
# 0         108     67.06      33.73        63.91
# 0          73     64.40      52.80        45.34
# 0         146     68.55      42.35        57.25
# 0         150     61.97      44.40        54.15
# 0         166     79.53      37.13        61.03
# 0         146     73.82      39.84        58.17
# 0         135     79.67      41.84        56.49
# 0         111     69.40      38.71        59.68
# 0         167     76.49      44.66        54.05
# 0         118     71.79      40.80        58.71
# 0          99     83.04      45.70        53.23
# 0         144     78.16      40.89        58.30
# 0          76     57.49      42.96        53.52
# 0          82     59.15      35.25        58.99
# 0          39     53.23      40.91        59.09
# 0         187     70.05      36.98        60.13
# 0          58     67.55      42.16        56.86
# 0          60     58.29      43.12        55.05
# 0         108     72.03      39.89        57.45
# 0          69     73.03      46.15        53.08
# 0          89     62.85      42.77        55.97
# 0          42     59.86      49.41        49.41
# 0          42     58.59      41.33        56.00
# 0          46     50.35      36.11        63.89
# 0          89     69.20      44.51        54.27
# 0          88     71.54      51.61        47.31
# 0          66     67.54      48.06        51.16
# 0          85     59.46      51.14        48.30
# 0         140     77.17      40.83        58.33
# 0          98     72.87      46.28        52.13
# 0          65     72.93      48.48        49.24
# 0          73     65.83      42.75        55.73
# 0         168     71.72      31.71        68.29

# %%
# adjust the df index 

df3.set_index("session name", inplace = True) 

#add new column to existing df
# creating a new column session_number 
df3['session_number'] = ''
df3['session_number'][0] = 0
for i in range(1,len(df3)): 
    df3['session_number'][i] = (df3['session_number'][i-1]) +1
df3
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       all trials  correct trials  diff contrast t  no contras  \
# session name
# Cori_2016-12-14              214             141               57          84
# Cori_2016-12-17              251             159               57          98
# Cori_2016-12-18              228             151               55          93
# Forssmann_2017-11-01         249             166               50         112
# Forssmann_2017-11-02         254             168               67          94
# Forssmann_2017-11-04         290             215               81         129
# Forssmann_2017-11-05         252             169               57         108
# Hench_2017-06-15             250             161               85          73
# Hench_2017-06-16             372             255              108         146
# Hench_2017-06-17             447             277              123         150
# Hench_2017-06-18             342             272              101         166
# Lederberg_2017-12-05         340             251              100         146
# Lederberg_2017-12-06         300             239              100         135
# Lederberg_2017-12-07         268             186               72         111
# Lederberg_2017-12-08         404             309              138         167
# Lederberg_2017-12-09         280             201               82         118
# Lederberg_2017-12-10         224             186               85          99
# Lederberg_2017-12-11         316             247              101         144
# Moniz_2017-05-15             247             142               61          76
# Moniz_2017-05-16             235             139               49          82
# Moniz_2017-05-18             124              66               27          39
# Muller_2017-01-07            444             311              115         187
# Muller_2017-01-08            151             102               43          58
# Muller_2017-01-09            187             109               47          60
# Radnitz_2017-01-08           261             188               75         108
# Radnitz_2017-01-09           178             130               60          69
# Radnitz_2017-01-10           253             159               68          89
# Radnitz_2017-01-11           142              85               42          42
# Radnitz_2017-01-12           128              75               31          42
# Richards_2017-10-29          143              72               26          46
# Richards_2017-10-30          237             164               73          89
# Richards_2017-10-31          260             186               96          88
# Richards_2017-11-01          191             129               62          66
# Richards_2017-11-02          296             176               90          85
# Tatum_2017-12-06             311             240               98         140
# Tatum_2017-12-07             258             188               87          98
# Tatum_2017-12-08             181             132               64          65
# Tatum_2017-12-09             199             131               56          73
# Theiler_2017-10-11           343             246               78         168
#
#                       %Correct  %Contrast  % 0contrast session_number
# session name
# Cori_2016-12-14          65.89      40.43        59.57              0
# Cori_2016-12-17          63.35      35.85        61.64              1
# Cori_2016-12-18          66.23      36.42        61.59              2
# Forssmann_2017-11-01     66.67      30.12        67.47              3
# Forssmann_2017-11-02     66.14      39.88        55.95              4
# Forssmann_2017-11-04     74.14      37.67        60.00              5
# Forssmann_2017-11-05     67.06      33.73        63.91              6
# Hench_2017-06-15         64.40      52.80        45.34              7
# Hench_2017-06-16         68.55      42.35        57.25              8
# Hench_2017-06-17         61.97      44.40        54.15              9
# Hench_2017-06-18         79.53      37.13        61.03             10
# Lederberg_2017-12-05     73.82      39.84        58.17             11
# Lederberg_2017-12-06     79.67      41.84        56.49             12
# Lederberg_2017-12-07     69.40      38.71        59.68             13
# Lederberg_2017-12-08     76.49      44.66        54.05             14
# Lederberg_2017-12-09     71.79      40.80        58.71             15
# Lederberg_2017-12-10     83.04      45.70        53.23             16
# Lederberg_2017-12-11     78.16      40.89        58.30             17
# Moniz_2017-05-15         57.49      42.96        53.52             18
# Moniz_2017-05-16         59.15      35.25        58.99             19
# Moniz_2017-05-18         53.23      40.91        59.09             20
# Muller_2017-01-07        70.05      36.98        60.13             21
# Muller_2017-01-08        67.55      42.16        56.86             22
# Muller_2017-01-09        58.29      43.12        55.05             23
# Radnitz_2017-01-08       72.03      39.89        57.45             24
# Radnitz_2017-01-09       73.03      46.15        53.08             25
# Radnitz_2017-01-10       62.85      42.77        55.97             26
# Radnitz_2017-01-11       59.86      49.41        49.41             27
# Radnitz_2017-01-12       58.59      41.33        56.00             28
# Richards_2017-10-29      50.35      36.11        63.89             29
# Richards_2017-10-30      69.20      44.51        54.27             30
# Richards_2017-10-31      71.54      51.61        47.31             31
# Richards_2017-11-01      67.54      48.06        51.16             32
# Richards_2017-11-02      59.46      51.14        48.30             33
# Tatum_2017-12-06         77.17      40.83        58.33             34
# Tatum_2017-12-07         72.87      46.28        52.13             35
# Tatum_2017-12-08         72.93      48.48        49.24             36
# Tatum_2017-12-09         65.83      42.75        55.73             37
# Theiler_2017-10-11       71.72      31.71        68.29             38

# %%
#to save
#df3.to_csv (r'/Users/kcenia/Documents/GitHub/NMA_project/kce/trials_comparison_df.csv', index = False, header=True)

# %% [markdown]
# ## To plot the trials

# %%
df4 = df3['%Correct']
#df4 = pd.concat([df4, df3['all trials']], axis=1, sort=False)
df4 = pd.concat([df4, df3['%Contrast']], axis=1, sort=False)
df4 = pd.concat([df4, df3['% 0contrast']], axis=1, sort=False)  

figure = df4.plot.bar(figsize=(20,10));

# %%
#save the figure
figure.figure.savefig('trials_comparison.png')
